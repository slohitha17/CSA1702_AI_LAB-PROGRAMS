# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=[1,2,3]
L.append(4)
print("Append:",L)
L.extend([5,6])
print("Extend:",L)
L.insert(0,0)
print("Add:",L)
L.remove(3)
print("Delete:",L)
# Out:
# Append: [1, 2, 3, 4]
# Extend: [1, 2, 3, 4, 5, 6]
# Add: [0, 1, 2, 3, 4, 5, 6]
# Delete: [0, 1, 2, 4, 5, 6]
