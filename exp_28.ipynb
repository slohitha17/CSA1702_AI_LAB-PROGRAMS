# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {
    "Math": ("Ravi", "M101"),
    "Science": ("Anu", "S101")
}

subject = input("Enter subject: ")
teacher, code = data.get(subject, ("Not found", "Not found"))

print("Teacher =", teacher)
print("Subject Code =", code)
# Out:
# Enter subject: math
# Teacher = Not found
# Subject Code = Not found
