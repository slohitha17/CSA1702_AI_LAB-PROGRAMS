# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monkey = input("Enter monkey position: ")
box = input("Enter box position: ")

print("Monkey moves to box")
print("Monkey climbs the box")
print("Monkey gets banana")
# Out:
# Enter monkey position: door
# Enter box position: room
# Monkey moves to box
# Monkey climbs the box
# Monkey gets banana
