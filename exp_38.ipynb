# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
facts = ["sunny", "warm"]

if "sunny" in facts and "warm" in facts:
    facts.append("good_day")

if "good_day" in facts:
    print("It is a good day")
# Out:
# It is a good day
