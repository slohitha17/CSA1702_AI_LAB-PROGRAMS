# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
room={'A':'Dirty','B':'Dirty'}
pos='A'

while 'Dirty' in room.values():
    print("Clean",pos)
    room[pos]='Clean'
    pos='B' if pos=='A' else 'A'

print("Room status:",room)
# Out:
# Clean A
# Clean B
# Room status: {'A': 'Clean', 'B': 'Clean'}
