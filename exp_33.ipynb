# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
diet = {
    "underweight": "High Calorie Diet",
    "normal": "Balanced Diet",
    "overweight": "Low Calorie Diet"
}

x = input("Enter category: ").lower()
print("Diet =", diet.get(x, "Not found"))
# Out:
# Enter category: underweight
# Diet = High Calorie Diet
