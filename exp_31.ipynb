# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
birds = ["sparrow", "parrot", "eagle"]

bird = input("Enter bird: ").lower()

if bird in birds:
    print("Can fly")
elif bird == "penguin":
    print("Cannot fly")
else:
    print("Bird not found")
# Out:
# Enter bird: parrot
# Can fly
