# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
html = """
<html>
<head>
<title>My Web Blog</title>
</head>
<body>
<h1>My AI Blog</h1>
<p>Welcome to my blog.</p>
<a href="https://www.google.com">Visit Google</a>
</body>
</html>
"""

print(html)
# Out:
# <html>
# <head>
# <title>My Web Blog</title>
# </head>
# <body>
# <h1>My AI Blog</h1>
# <p>Welcome to my blog.</p>
# <a href="https://www.google.com">Visit Google</a>
# </body>
# </html>
