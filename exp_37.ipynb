# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
disease = {
    "fever": "Cold",
    "cough": "Flu",
    "rash": "Measles"
}

symptom = input("Enter symptom: ").lower()
print("Disease =", disease.get(symptom, "Unknown"))
# Out:
# Enter symptom: cold
# Disease = Unknown
