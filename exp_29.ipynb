# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
planets = {
    "Mercury": "Rocky",
    "Venus": "Rocky",
    "Earth": "Rocky",
    "Jupiter": "Gas"
}

p = input("Enter planet: ")
print("Type =", planets.get(p, "Not found"))
# Out:
# Enter planet: Earth
# Type = Rocky
