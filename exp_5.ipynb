# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=[[1,2],[3,4]]
print("Nested:",L)
print("Length:",len(L))
print("Concatenation:",L+[5,6])
print("Membership:",3 in L[1])
print("Iteration:")
for x in L: print(x)
print("Index:",L[0][1])
print("Slicing:",L[0][:])
# Out:
# Nested: [[1, 2], [3, 4]]
# Length: 2
# Concatenation: [[1, 2], [3, 4], 5, 6]
# Membership: True
# Iteration:
# [1, 2]
# [3, 4]
# Index: 2
# Slicing: [1, 2]
