# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r,c=map(int,input("Rows Columns: ").split())
A=[list(map(int,input().split())) for _ in range(r)]

for j in range(c):
    print(*[A[i][j] for i in range(r)])
# Out:
# Rows Columns: 2 3
# 1 2 3
# 4 5 6
# 1 4
# 2 5
# 3 6
