# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = {
    "apple": "red",
    "banana": "yellow",
    "grape": "green",
    "orange": "orange"
}

fruit = input("Enter fruit: ").lower()
print("Color =", fruits.get(fruit, "Not found"))
# Out:
# Enter fruit: banana
# Color = yellow
