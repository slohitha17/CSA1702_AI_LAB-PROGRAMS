# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
db = {
    "lohitha": "10-05-2006",
    "rahul": "15-08-2005",
    "anu": "20-12-2006"
}

name = input("Enter name: ")
print("DOB =", db.get(name, "Not found"))
# Out:
# Enter name: lohitha
# DOB = 10-05-2006
