# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=set(map(int,input("Set A: ").split()))
B=set(map(int,input("Set B: ").split()))

print("Union:",A|B)
print("Intersection:",A&B)
print("Difference:",A-B)
print("Symmetric Difference:",A^B)
# Out:
# Set A: 1 2 3 4
# Set B: 3
# Union: {1, 2, 3, 4}
# Intersection: {3}
# Difference: {1, 2, 4}
# Symmetric Difference: {1, 2, 4}
