# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702_AI_LAB-PROGRAMS/blob/main/exp_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

a,b=map(int,input("Capacities: ").split())
target=int(input("Target: "))
q=deque([((0,0),[])])
seen=set()

while q:
    (x,y),p=q.popleft()
    if x==target or y==target:
        print(*p,sep="\n"); break
    if (x,y) in seen: continue
    seen.add((x,y))
    states=[(a,y),(x,b),(0,y),(x,0),
            (x-min(x,b-y),y+min(x,b-y)),
            (x+min(y,a-x),y-min(y,a-x))]
    for s in states:q.append((s,p+[s]))
# Out:
# Capacities: 4 3
# Target: 2
# (0, 3)
# (3, 0)
# (3, 3)
# (4, 2)
